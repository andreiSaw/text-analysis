# %%
import fasttext
import pandas as pd
import json

# %%
json_lines=[]
with open("tpc-dataset.train.txt",'r') as f:
    for line in f:
        json_lines.append(json.loads(line))

# %%
df=pd.DataFrame.from_dict(json_lines)

# %%
df
# Out:
#         age education         id  \
# 0     35-44       NaN  324781705
# 1     25-34       NaN  971569377
# 2     35-44       NaN  904248160
# 3     25-34       NaN  422973224
# 4     25-34       NaN  290290951
# 5     25-34       NaN  614886771
# 6     18-24       NaN  123781249
# 7     18-24       NaN  875504604
# 8     18-24       NaN  315768777
# 9     25-34       NaN  175352533
# 10    25-34       NaN  701663381
# 11    18-24       NaN  408343138
# 12    25-34       NaN  284572699
# 13    18-24       NaN  685982583
# 14    25-34       NaN  385460024
# 15    18-24       NaN  186866710
# 16    25-34       NaN  859985073
# 17    25-34       NaN  912795214
# 18     <=17       NaN  661915758
# 19    18-24       NaN  100689314
# 20    25-34       NaN  461685536
# 21    18-24       NaN  705054813
# 22     <=17       NaN  576186944
# 23    25-34       NaN  875656235
# 24    25-34       NaN  152253021
# 25    25-34       NaN  962711508
# 26    25-34       NaN  433502504
# ...
